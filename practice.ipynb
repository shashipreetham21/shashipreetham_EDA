# %%
import pandas as pd
import numpy as py
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=r"C:\Users\SHASHI PREETHAM\Documents\Nareshit\EDA\Visadataset - Visadataset.csv"
pd.read_csv(path)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
import matplotlib.pyplot as plt
pd.read_csv(path)
pd.read_csv(path)

# %%
path=r"C:\Users\SHASHI PREETHAM\Documents\Nareshit\EDA\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(path)
visa_df.head(5)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
visa_df=pd.read_csv(path)
visa_df.head(6)

visa_df=pd.read_csv(path)
visa_df.head(8)
visa_df.head(3)

# %%
path=r"C:\Users\SHASHI PREETHAM\Documents\Nareshit\EDA\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(path)
visa_df.head(8)
# Out:
#   case_id      continent education_of_employee has_job_experience  \
# 0  EZYV01           Asia           High School                  N
# 1  EZYV02           Asia              Master's                  Y
# 2  EZYV03           Asia            Bachelor's                  N
# 3  EZYV04           Asia            Bachelor's                  N
# 4  EZYV05         Africa              Master's                  Y
# 5  EZYV06           Asia              Master's                  Y
# 6  EZYV07           Asia            Bachelor's                  N
# 7  EZYV08  North America            Bachelor's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib.pyplot as plt
plt.hist(visa_df['prevailing_wage'],bins=40)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(visa_df["prevailing_wage"],bins=40)
plt.show()

# %%
import matplotlib.pyplot as plt
f,i,n=plt.hist(visa_df["prevailing_wage"],bins=40)
plt.show()

# %%
len(f),len(i),len(n)
# Out:
# (40, 41, 40)

# %%
plt.boxplot(visa_df["prevailing_wage"],vert=True)
plt.show()

#black dots are outliers
#orange line is median

# %%
plt.hist(visa_df["prevailing_wage"])
plt.hist(non_outliers_df["prevailing_wage"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 plt.hist(visa_df["prevailing_wage"])
# ----> 2 plt.hist(non_outliers_df["prevailing_wage"])
#       3 plt.show()
#
# NameError: name 'non_outliers_df' is not defined

# %%
plt.hist(non_outliers_df["prevailing_wage"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 plt.hist(non_outliers_df["prevailing_wage"])
#
# NameError: name 'non_outliers_df' is not defined

# %%
name=['ramesh','suresh','shashi']
age=[20,20,30]
name,age
# Out:
# (['ramesh', 'suresh', 'shashi'], [20, 20, 30])

# %%
pd.DataFrame(zip(name,age))
# Out:
#         0   1
# 0  ramesh  20
# 1  suresh  20
# 2  shashi  30

# %%
data=zip(name,age)
cols=['name','age']
pd.DataFrame(data,columns=cols)
# Out:
#      name  age
# 0  ramesh   20
# 1  suresh   20
# 2  shashi   30

# %%
data=zip(name,age)
cols=['name','age']
ind=['a','b','c']
df=pd.DataFrame(data,columns=cols,index=ind)
df
# Out:
#      name  age
# a  ramesh   20
# b  suresh   20
# c  shashi   30

# %%
city_names=['hyd','chennai','blr']
df['city']=city_names
df
# Out:
#      name  age     city
# a  ramesh   20      hyd
# b  suresh   20  chennai
# c  shashi   30      blr

# %%
path=path=r"C:\Users\SHASHI PREETHAM\Documents\Nareshit\EDA\Visadataset - Visadataset.csv"
pd.read_csv(path)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
path=path=r"C:\Users\SHASHI PREETHAM\Documents\Nareshit\EDA\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(path)
visa_df.head(8)
# Out:
#   case_id      continent education_of_employee has_job_experience  \
# 0  EZYV01           Asia           High School                  N
# 1  EZYV02           Asia              Master's                  Y
# 2  EZYV03           Asia            Bachelor's                  N
# 3  EZYV04           Asia            Bachelor's                  N
# 4  EZYV05         Africa              Master's                  Y
# 5  EZYV06           Asia              Master's                  Y
# 6  EZYV07           Asia            Bachelor's                  N
# 7  EZYV08  North America            Bachelor's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# ...

# %%
visa_df=pd.read_csv(path)
visa_df.head(7)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
# 5  EZYV06      Asia              Master's                  Y
# 6  EZYV07      Asia            Bachelor's                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
# ...

# %%
visa_df.head(8)
# Out:
#   case_id      continent education_of_employee has_job_experience  \
# 0  EZYV01           Asia           High School                  N
# 1  EZYV02           Asia              Master's                  Y
# 2  EZYV03           Asia            Bachelor's                  N
# 3  EZYV04           Asia            Bachelor's                  N
# 4  EZYV05         Africa              Master's                  Y
# 5  EZYV06           Asia              Master's                  Y
# 6  EZYV07           Asia            Bachelor's                  N
# 7  EZYV08  North America            Bachelor's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# ...

# %%
visa_df=pd.read_csv(path)
visa_df.head(8)
# Out:
#   case_id      continent education_of_employee has_job_experience  \
# 0  EZYV01           Asia           High School                  N
# 1  EZYV02           Asia              Master's                  Y
# 2  EZYV03           Asia            Bachelor's                  N
# 3  EZYV04           Asia            Bachelor's                  N
# 4  EZYV05         Africa              Master's                  Y
# 5  EZYV06           Asia              Master's                  Y
# 6  EZYV07           Asia            Bachelor's                  N
# 7  EZYV08  North America            Bachelor's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
name=['ramesh','suresh','rajesh']
age=[20,30,40]
name,age
# Out:
# (['ramesh', 'suresh', 'rajesh'], [20, 30, 40])

# %%
pd.DataFrame()

# %%
pd.DataFrame(zip(name,age))
# Out:
#         0   1
# 0  ramesh  20
# 1  suresh  30
# 2  rajesh  40

# %%
(zip(name,age))
cols=['name','age']
pd.DataFrame(zip(name,age),columns=cols)
# Out:
#      name  age
# 0  ramesh   20
# 1  suresh   30
# 2  rajesh   40

# %%
data=(zip(name,age))
cols=['name','age']
pd.DataFrame(data,columns=cols)
# Out:
#      name  age
# 0  ramesh   20
# 1  suresh   30
# 2  rajesh   40

# %%
data=(zip(name,age))
cols=['name','age']
ind=['a','b','c']
pd.DataFrame(data,columns=cols,index=ind)
# Out:
#      name  age
# a  ramesh   20
# b  suresh   30
# c  rajesh   40

# %%
pd.DataFrame()
zip(name,age)

# %%
data=zip(name,age)
cols=['name','age']
ind=['a','b','c']
df=pd.DataFrame(data,index=ind,columns=cols)
df
# Out:
#      name  age
# a  ramesh   20
# b  rajesh   20
# c  suresh   30

# %%
city_names=['hyd','blr','chennai']
df['city']=city_names
df
# Out:
#      name  age     city
# a  ramesh   20      hyd
# b  rajesh   20      blr
# c  suresh   30  chennai

# %%
df['name']=['swamy','shashi','ramesh']
df
# Out:
#      name  age     city
# a   swamy   20      hyd
# b  shashi   20      blr
# c  ramesh   30  chennai

# %%
name=['ramesh','rajesh','suresh']
age=[20,30,40]
zip(name,age)
cols=['name','age']
ind=['a','b','c']
city_names=['hyd','blr','mp']
df['city']=city_names
df=pd.DataFrame(zip(name,age),index=ind,columns=cols)
df
# Out:
#      name  age
# a  ramesh   20
# b  rajesh   30
# c  suresh   40

# %%
df['city']='up','hyd','blr'
df
# Out:
#      name  age city
# a   swamy   20   up
# b  shashi   20  hyd
# c  ramesh   30  blr

# %%
df.drop('c',
       axis=0,
       inplace=True)
df
# Out:
#      name  age
# a  ramesh   20
# b  rajesh   20

# %%
to drop column, axis=1
to drop rows,axis=0
inplace=True

# %%
name=['ramesh','rajesh','suresh']
age=[20,20,30]
data=zip(name,age)
cols=['name','age']
ind=['a','b','c']
df=pd.DataFrame(data,
                columns=cols,
                index=ind)
city_names=['pjb','mp','up']
df['city']=city_names

df.drop=('city',
        axis=1,
        inplace=True)
df
# Out:
#   Cell In[46], line 13
#     axis=1,
#     ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
df.drop=(columns name,column[axis=1] or rows[axis=0],inplace=True)

# %%
df.to_csv('output.csv')
df.to_excel("output.xlsx")

# %%
pd.read_csv("output.csv")
# Out:
#      name  age
# 0  ramesh   30
# 1  suresh   40

# %%
d1={"NAME":['ramesh','rajesh','suresh'],"AGE":[20,30,40]}
pd.DataFrame(d1)
# Out:
#      NAME  AGE
# 0  ramesh   20
# 1  rajesh   30
# 2  suresh   40

# %%
d1={'NAME':['ramesh','suresh','rajesh'],'AGE':[20,30,40]}
pd.DataFrame(d1)
# Out:
#      NAME  AGE
# 0  ramesh   20
# 1  suresh   30
# 2  rajesh   40

# %%
d1={"NAME":['rajesh','ramesh','suresh'],"AGE":[10,20,30]}
pd.DataFrame(d1)
# Out:
#      NAME  AGE
# 0  rajesh   10
# 1  ramesh   20
# 2  suresh   30

# %%
pd.drop(column_name,column[axis=1],row[axis=0],inplace=True)

# %%
column_name=
df['column']=
df['column_name]=
